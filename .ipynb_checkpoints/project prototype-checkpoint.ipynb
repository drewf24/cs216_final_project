# %%
import pandas as pd
n_movies = pd.read_csv('n_movies.csv')
#n_movies.head()

# %%
n_movies['genre'] = n_movies['genre'].str.split(', ')

# %%
wrangled_n_movies = n_movies.loc[n_movies["rating"].notnull()]
#wrangled_n_movies.head(10)

# %%
netflix_titles = pd.read_csv("netflix_titles.csv")
netflix_titles['certificate'] = netflix_titles['rating']
netflix_titles.drop('rating', axis=1, inplace=True)
netflix_titles.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year   duration  \
# 0  September 25, 2021          2020     90 min
# 1  September 24, 2021          2021  2 Seasons
# 2  September 24, 2021          2021   1 Season
# 3  September 24, 2021          2021   1 Season
# 4  September 24, 2021          2021  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description certificate
# 0  As her father nears the end of his life, filmm...       PG-13
# 1  After crossing paths at a party, a Cape Town t...       TV-MA
# 2  To protect his family from a powerful drug lor...       TV-MA
# 3  Feuds, flirtations and toilet talk go down amo...       TV-MA
# 4  In a city of coaching centers known to train I...       TV-MA

# %%
merged_data = netflix_titles.merge(wrangled_n_movies, how='inner', on='title') #inner join on title
#print(merged_data)
merged_data.rename(columns={'duration_x':'seasons / movie length', 'duration_y': 'episode / movie length'}, inplace=True)

#get rid of trailing 'min' in episode / movie length column:
merged_data['episode / movie length'] = merged_data['episode / movie length'].replace(r'min$' , regex = True, value='')

#turn values in episode / movie length column to float so we can perform computations on them:
merged_data['episode / movie length'] = merged_data['episode / movie length'].astype(float)

#get rid of trailing 'min' in seasons / movie length column:
merged_data['seasons / movie length'] = merged_data['seasons / movie length'].replace(r'min$' , regex = True, value='')

merged_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s2  TV Show          Blood & Water              NaN
# 3      s3  TV Show              Ganglands  Julien Leclercq
# 4      s4  TV Show  Jailbirds New Orleans              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 3  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 4                                                NaN            NaN
#
#            date_added  release_year seasons / movie length  \
# 0  September 25, 2021          2020                    90
# 1  September 24, 2021          2021              2 Seasons
# 2  September 24, 2021          2021              2 Seasons
# 3  September 24, 2021          2021               1 Season
# 4  September 24, 2021          2021               1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2    International TV Shows, TV Dramas, TV Mysteries
# 3  Crime TV Shows, International TV Shows, TV Act...
# 4                             Docuseries, Reality TV
#
#                                        description_x certificate_x      year  \
# 0  As her father nears the end of his life, filmm...         PG-13    (2020)
# 1  After crossing paths at a party, a Cape Town t...         TV-MA  (2020– )
# 2  After crossing paths at a party, a Cape Town t...         TV-MA  (2020– )
# 3  To protect his family from a powerful drug lor...         TV-MA  (2021– )
# 4  Feuds, flirtations and toilet talk go down amo...         TV-MA  (2021– )
#
#   certificate_y  episode / movie length                            genre  \
# 0         PG-13                    89.0  [Documentary, Biography, Drama]
# 1         TV-MA                    53.0                 [Drama, Mystery]
# 2         TV-MA                    43.0                 [Drama, Mystery]
# 3         TV-MA                    44.0           [Action, Crime, Drama]
# 4         TV-MA                     NaN        [Documentary, Reality-TV]
#
#    rating                                      description_y  \
# 0     7.4  A daughter helps her father prepare for the en...
# 1     6.6  A local teen uncovers her family's secret past...
# 2     7.0  Puleng bears her parents' complex sadness as e...
# 3     7.0  Mehdi, a qualified robber, and Liana, an appre...
# 4     6.7  Feuds, flirtations and toilet talk go down amo...
#
#                                                stars  votes
# 0  ['Kirsten Johnson', '| ', '    Stars:', 'Micha...  6,636
# 1  ['Ama Qamata, ', 'Khosi Ngema, ', 'Gail Mabala...  3,180
# 2  ['Nosipho Dumisa', '| ', '    Stars:', 'Ama Qa...    120
# 3  ['Tracy Gotoas, ', 'Sofia Lesaffre, ', 'Salim ...  2,640
# 4                                                 []    229

# %%
#group by title to get average rating for title - this is needed because individual episodes are listed, 
#so we want the average rating for a show based on individual episode ratings: 
grouped_rating= merged_data.groupby('title')['rating'].mean().to_frame().reset_index()

#renaming this column for clarity:
grouped_rating.rename(columns={'rating':'average rating'}, inplace=True)

#group by title to get average length of the episode / movie - this is needed for the same reason listed above
grouped_episode_duration = merged_data.groupby('title')['episode / movie length'].mean().to_frame().reset_index()

grouped_episode_duration.rename(columns={'episode / movie length':'average episode / movie length'}, inplace=True)

# %%
#making a copy of the merged data set to preserve the original one:
merged_data_copy = merged_data.copy()

#merge rating group by with merged data set to get a column with average rating
merge_average_rating = pd.merge(merged_data_copy, grouped_rating)

#merge the new df with the average rating column with average episode duration
merge_with_two_avg_col = pd.merge(merge_average_rating, grouped_episode_duration)

#same as the original merged_data, but now has two columns for average rating and average episode / movie length
# Out:
#      show_id     type                                         title  \
# 4612   s8545  TV Show                                 The Underwear
# 4613   s8574    Movie                                Theo Who Lived
# 4614   s8575  TV Show                              ThirTEEN Terrors
# 4615   s8579    Movie                                        Thithi
# 4616   s8586    Movie                         Three-Quarters Decent
# 4617   s8591    Movie                          Tikli and Laxmi Bomb
# 4618   s8610  TV Show                                        Towies
# 4619   s8613    Movie                             Train of the Dead
# 4620   s8620    Movie  Treasures from the Wreck of the Unbelievable
# 4621   s8632    Movie                   Trixie Mattel: Moving Parts
# 4622   s8634  TV Show                                       Trotsky
# 4623   s8645  TV Show                                    Twin Peaks
# 4624   s8647  TV Show                                    Twirlywoos
# 4625   s8649    Movie                                    Two Graves
# 4626   s8650    Movie                         Two Lovers and a Bear
# 4627   s8653    Movie                                          Ugly
# 4628   s8664    Movie                                Unruly Friends
# 4629   s8666    Movie                                          Urvi
# 4630   s8667    Movie                                    Used Goods
# 4631   s8670  TV Show                                 V.R. Troopers
# 4632   s8675    Movie                               Viceroy's House
# 4633   s8681    Movie                        Viswasapoorvam Mansoor
# 4634   s8727  TV Show                          When Calls the Heart
# 4635   s8746    Movie           Willy Wonka & the Chocolate Factory
# 4636   s8766    Movie                                            XX
# 4637   s8776  TV Show                               Yeh Meri Family
# 4638   s8778    Movie                                     Yes or No
# 4639   s8789    Movie                                  You Carry Me
# 4640   s8803    Movie                                        Zodiac
# 4641   s8804  TV Show                                   Zombie Dumb
#
#                                                director  \
# 4612                                                NaN
# 4613                                     David Shisgall
# 4614                                                NaN
# 4615                                         Raam Reddy
# 4616                                      Mohamed Hamdy
# 4617                                   Aditya Kripalani
# 4618                                                NaN
# 4619                                 Sukum Maetawanitch
# 4620                                      Sam Hobkinson
# 4621                                Nicholas Zeig-Owens
# 4622                                                NaN
# 4623                                                NaN
# 4624                                                NaN
# 4625                                         Gary Young
# 4626                                         Kim Nguyen
# 4627                                     Anurag Kashyap
# 4628                                     Sherif Mandour
# 4629                                      Pradeep Verma
# 4630                                      Mohamed Hamdy
# 4631                                                NaN
# 4632                                    Gurinder Chadha
# 4633                                P.T. Kunju Muhammad
# 4634                                                NaN
# 4635                                         Mel Stuart
# 4636  Jovanka Vuckovic, Annie Clark, Roxanne Benjami...
# 4637                                                NaN
# 4638                            Saratswadee Wongsomphet
# 4639                                         Ivona Juka
# 4640                                      David Fincher
# 4641                                                NaN
#
#                                                    cast  \
# 4612  Thanabordee Jaiyen, Emika Grant Emma, Tantimed...
# 4613                                                NaN
# 4614  Thanapatpisal Sananthachat, Panisara Montharat...
# 4615  Thammegowda S., Channegowda, Abhishek H.N., Po...
# 4616  Mohamed Ragab, Lamitta Frangieh, Mohsen Mansou...
# 4617  Vibhawari Deshpande, Chitrangada Chakraborty, ...
# 4618                                                NaN
# 4619  Kett Thantup, Savika Chaiyadej, Sura Theerakon...
# 4620                                                NaN
# 4621                                       Brian Firkus
# 4622  Konstantin Khabenskiy, Olga Sutulova, Max Matv...
# 4623  Kyle MacLachlan, Michael Ontkean, Mädchen Amic...
# 4624                                      Linda Bassett
# 4625  Cathy Tyson, Katie Jarvis, David Hayman, Josh ...
# 4626  Dane DeHaan, Tatiana Maslany, Gordon Pinsent, ...
# 4627  Rahul Bhat, Ronit Roy, Tejaswini Kolhapure, Vi...
# 4628  Kinda Allouch, Ahmed Salah Al-Saadany, Dina Fo...
# 4629  Sruthi Hariharan, Shraddha Srinath, Shweta Pan...
# 4630      Mohamed Ragab, Ayten Amer, Hassan Abdulfattah
# 4631  Michael Sorich, Gardner Baldwin, Mike Reynolds...
# 4632  Hugh Bonneville, Gillian Anderson, Manish Daya...
# 4633  Roshan Mathew, Asha Sarath, Prayaga Martin, Za...
# 4634  Erin Krakow, Daniel Lissing, Lori Loughlin, Ma...
# 4635  Gene Wilder, Jack Albertson, Peter Ostrum, Roy...
# 4636  Natalie Brown, Jonathan Watton, Melanie Lynske...
# 4637  Vishesh Bansal, Mona Singh, Akarsh Khurana, Ah...
# 4638  Sushar Manaying, Supanart Jittaleela, Arisara ...
# 4639  Lana Baric, Vojislav Brajovic, Natasa Janjic, ...
# 4640  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 4641                                                NaN
#
#                                         country         date_added  \
# 4612                                        NaN      June 19, 2018
# 4613                              United States  December 16, 2016
# 4614                                   Thailand      March 1, 2019
# 4615                       India, United States      March 9, 2017
# 4616                                        NaN      June 20, 2019
# 4617                                      India     August 1, 2018
# 4618                                        NaN  December 27, 2017
# 4619                                   Thailand      July 25, 2018
# 4620                             United Kingdom    January 1, 2018
# 4621                              United States     March 27, 2020
# 4622                                     Russia  December 10, 2018
# 4623                              United States       July 1, 2017
# 4624                             United Kingdom       May 15, 2020
# 4625                             United Kingdom        May 1, 2019
# 4626                                     Canada        May 2, 2017
# 4627                                      India      March 1, 2017
# 4628                                      Egypt      June 20, 2019
# 4629                                      India   January 15, 2018
# 4630                                      Egypt  September 1, 2019
# 4631                              United States    January 1, 2016
# 4632              United Kingdom, India, Sweden  December 12, 2017
# 4633                                      India       July 1, 2018
# 4634                              United States  December 29, 2018
# 4635  United States, East Germany, West Germany    January 1, 2020
# 4636                      Canada, United States      June 22, 2017
# 4637                                      India    August 31, 2018
# 4638                                   Thailand   December 6, 2018
# 4639      Croatia, Slovenia, Serbia, Montenegro       July 1, 2016
# 4640                              United States  November 20, 2019
# 4641                                        NaN       July 1, 2019
#
#       release_year seasons / movie length  \
# 4612          2017               1 Season
# 4613          2016                    86
# 4614          2014               1 Season
# 4615          2015                   123
# 4616          2010                    96
# 4617          2017                   151
# 4618          2016               1 Season
# 4619          2007                    88
# 4620          2017                    82
# 4621          2019                    91
# 4622          2017               1 Season
# 4623          1990              2 Seasons
# 4624          2018              2 Seasons
# 4625          2018                    80
# 4626          2016                    95
# 4627          2013                   125
# 4628          2011                    83
# 4629          2017                   121
# 4630          2018                    95
# 4631          1995              2 Seasons
# 4632          2017                   106
# 4633          2017                   125
# 4634          2017              5 Seasons
# 4635          1971                   100
# 4636          2017                    81
# 4637          2018               1 Season
# 4638          2010                   111
# 4639          2015                   157
# 4640          2007                   158
# 4641          2018              2 Seasons
#
#                                               listed_in  ...         year  \
# 4612   International TV Shows, TV Dramas, Teen TV Shows  ...       (2017)
# 4613                                      Documentaries  ...       (2016)
# 4614    International TV Shows, TV Horror, TV Mysteries  ...  (2014–2015)
# 4615   Dramas, Independent Movies, International Movies  ...       (2015)
# 4616             Comedies, Dramas, International Movies  ...       (2010)
# 4617                       Dramas, International Movies  ...       (2017)
# 4618                 International TV Shows, Reality TV  ...     (2016– )
# 4619                Horror Movies, International Movies  ...       (2007)
# 4620        Documentaries, Dramas, International Movies  ...       (2017)
# 4621                    Documentaries, Music & Musicals  ...       (2019)
# 4622                  International TV Shows, TV Dramas  ...       (2017)
# 4623       Classic & Cult TV, Crime TV Shows, TV Dramas  ...  (1990–1991)
# 4624                         British TV Shows, Kids' TV  ...  (2015–2017)
# 4625                                          Thrillers  ...   (I) (2018)
# 4626        Dramas, Independent Movies, Romantic Movies  ...       (2016)
# 4627            Dramas, International Movies, Thrillers  ...       (2013)
# 4628                    International Movies, Thrillers  ...       (2012)
# 4629   Dramas, Independent Movies, International Movies  ...       (2017)
# 4630  Action & Adventure, Comedies, International Mo...  ...       (2018)
# 4631                                           Kids' TV  ...  (1994–1996)
# 4632                                             Dramas  ...       (2017)
# 4633                       Dramas, International Movies  ...       (2017)
# 4634                                          TV Dramas  ...     (2014– )
# 4635  Children & Family Movies, Classic Movies, Come...  ...       (1971)
# 4636                                      Horror Movies  ...       (2017)
# 4637                International TV Shows, TV Comedies  ...       (2018)
# 4638  International Movies, LGBTQ Movies, Romantic M...  ...       (2010)
# 4639                       Dramas, International Movies  ...       (2015)
# 4640                     Cult Movies, Dramas, Thrillers  ...       (2007)
# 4641             Kids' TV, Korean TV Shows, TV Comedies  ...     (2019– )
#
#      certificate_y episode / movie length                           genre  \
# 4612           NaN                   45.0                         [Drama]
# 4613           NaN                   86.0                   [Documentary]
# 4614           NaN                    NaN     [Horror, Mystery, Thriller]
# 4615           NaN                  123.0                         [Drama]
# 4616           NaN                   96.0                 [Comedy, Drama]
# 4617           NaN                  151.0                         [Drama]
# 4618           NaN                   30.0                    [Reality-TV]
# 4619         TV-14                   88.0        [Crime, Horror, Mystery]
# 4620           NaN                   90.0                   [Documentary]
# 4621           NaN                   91.0                   [Documentary]
# 4622           NaN                   50.0     [Biography, Drama, History]
# 4623         TV-MA                   47.0         [Crime, Drama, Mystery]
# 4624           NaN                   15.0             [Animation, Family]
# 4625         TV-MA                   80.0                      [Thriller]
# 4626             R                   96.0     [Adventure, Drama, Romance]
# 4627     Not Rated                  128.0         [Crime, Drama, Mystery]
# 4628           NaN                   85.0       [Drama, Mystery, Romance]
# 4629           NaN                  151.0        [Crime, Drama, Thriller]
# 4630           NaN                   95.0                 [Comedy, Drama]
# 4631         TV-Y7                   30.0     [Action, Adventure, Family]
# 4632     Not Rated                  106.0     [Biography, Drama, History]
# 4633           NaN                  112.0                         [Drama]
# 4634          TV-G                   43.0       [Drama, History, Romance]
# 4635             G                  100.0      [Family, Fantasy, Musical]
# 4636             R                   80.0                        [Horror]
# 4637         TV-14                   30.0         [Comedy, Drama, Family]
# 4638           NaN                  102.0               [Comedy, Romance]
# 4639       Unrated                  155.0                 [Action, Drama]
# 4640             R                  157.0         [Crime, Drama, Mystery]
# 4641         TV-Y7                    NaN  [Animation, Adventure, Comedy]
#
#       rating                                      description_y  \
# 4612     6.6  A story about the lives and relationships of y...
# 4613     6.8  A documentary on American journalist Theo Padn...
# 4614     6.8  A series of terrors of Thai supernatural force...
# 4615     8.0  In a South Indian village, a centenarian's fun...
# 4616     3.1  Cartoonist Hesham provides for his family and ...
# 4617     7.7  Two sex workers decide to kick men out of the ...
# 4618     6.2  An Australian towing company's staff take on a...
# 4619     3.5  Five teenagers : Joke (the gang-leader), trans...
# 4620     6.0  The fake story of the art found beneath the de...
# 4621     7.3  Trixie charmed audiences and judges as winner ...
# 4622     7.1  In May 1940, on the outskirts of Mexico City, ...
# 4623     8.8  An idiosyncratic FBI agent investigates the mu...
# 4624     7.3     The adventures of four inquisitive Twirlywoos.
# 4625     4.3  MARGARET POWERS, a middle aged, middle class d...
# 4626     6.0  Set in a small town near the North Pole where ...
# 4627     8.0  The case of a missing girl takes us through a ...
# 4628     5.4  Mona is suffering from a family problems betwe...
# 4629     6.8  Troubling circumstances bring forward three wo...
# 4630     4.3  An international organization tries to kidnap ...
# 4631     5.6  A trio of teenagers gain powers from "Virtual ...
# 4632     6.7  The final Viceroy of India, Louis Francis Albe...
# 4633     5.9  Set against the background of certain social u...
# 4634     7.9  Elizabeth Thatcher, a young school teacher fro...
# 4635     7.8  A poor but hopeful boy seeks one of the five c...
# 4636     4.6  Four short horror films that are directed and ...
# 4637     9.1  Set in the summer of 1998 it is a story about ...
# 4638     6.7  Pie is a sweet girl who moves into a new colle...
# 4639     7.0  Three daughters battle for acceptance, redempt...
# 4640     7.7  Between 1968 and 1983, a San Francisco cartoon...
# 4641     5.6                                         Add a Plot
#
#                                                   stars    votes  \
# 4612  ['Natthacha De Souza, ', 'Emma Emika Grant, ',...        9
# 4613  ['David Schisgall', '| ', '    Star:', 'Theo P...      117
# 4614  ['Sananthachat Thanapatpisal, ', 'Thiti Mahayo...      306
# 4615  ['Raam Reddy', '| ', '    Stars:', 'Thammegowd...    2,721
# 4616  ['Mohamed Hamdy', '| ', '    Stars:', 'Mahmood...       38
# 4617  ['Aditya Kripalani', '| ', '    Stars:', 'Chit...    7,617
# 4618  ['Adrian Jarrett, ', 'Mike, ', 'Spooney, ', 'J...        6
# 4619  ['Sukhum Mathawanit', '| ', '    Stars:', 'Ket...      383
# 4620  ['Sam Hobkinson', '| ', '    Stars:', 'Damien ...    1,482
# 4621  ['Nicholas Zeig-Owens', '| ', '    Stars:', 'T...    2,028
# 4622  ['Konstantin Khabenskiy, ', 'Mikhail Porechenk...    2,054
# 4623  ['Kyle MacLachlan, ', 'Michael Ontkean, ', 'Mä...  196,192
# 4624  ['Linda Bassett, ', 'Neil Nunes, ', 'Zaff Mali...      146
# 4625  ['Gary Young', '| ', '    Stars:', 'David Haym...      388
# 4626  ['Kim Nguyen', '| ', '    Stars:', 'Tatiana Ma...    1,947
# 4627  ['Anurag Kashyap', '| ', '    Stars:', 'Rahul ...   22,068
# 4628  ['Sherif Mandour', '| ', '    Stars:', 'Tamim ...      126
# 4629  ['B.S.Pradeep Varma', '| ', '    Stars:', 'Shw...      260
# 4630  ['Mohamed Hamdy', '| ', '    Stars:', 'Muhamma...      136
# 4631  ['Michael Hollander, ', 'Michael Sorich, ', 'D...    1,041
# 4632  ['Gurinder Chadha', '| ', '    Stars:', 'Hugh ...    8,032
# 4633  ['P.T. Kunju Muhammad', '| ', '    Stars:', 'S...       60
# 4634  ['Erin Krakow, ', 'Martin Cummins, ', 'Pascale...   13,133
# 4635  ['Mel Stuart', '| ', '    Stars:', 'Gene Wilde...  200,703
# 4636  ['Roxanne Benjamin, ', 'Sofìa Carrillo, ', 'Ka...   11,864
# 4637  ['Vishesh Bansal, ', 'Mona Singh, ', 'Akarsh K...   23,865
# 4638  ['Saratswadee Wongsomphet', '| ', '    Stars:'...    1,981
# 4639  ['Ivona Juka', '| ', '    Stars:', 'Helena Bel...    2,261
# 4640  ['David Fincher', '| ', '    Stars:', 'Jake Gy...  536,068
# 4641                                                 []       20
#
#      average rating average episode / movie length
# 4612            6.6                           45.0
# 4613            6.8                           86.0
# 4614            6.8                            NaN
# 4615            8.0                          123.0
# 4616            3.1                           96.0
# 4617            7.7                          151.0
# 4618            6.2                           30.0
# 4619            3.5                           88.0
# 4620            6.0                           90.0
# 4621            7.3                           91.0
# 4622            7.1                           50.0
# 4623            8.8                           47.0
# 4624            7.3                           15.0
# 4625            4.3                           80.0
# 4626            6.0                           96.0
# 4627            8.0                          128.0
# 4628            5.4                           85.0
# 4629            6.8                          151.0
# 4630            4.3                           95.0
# 4631            5.6                           30.0
# 4632            6.7                          106.0
# 4633            5.9                          112.0
# 4634            7.9                           43.0
# 4635            7.8                          100.0
# 4636            4.6                           80.0
# 4637            9.1                           30.0
# 4638            6.7                          102.0
# 4639            7.0                          155.0
# 4640            7.7                          157.0
# 4641            5.6                            NaN
#
# [30 rows x 22 columns]

# %%
#make a copy of the df above with the two average columns to have final cleaned data set
cleaned_data_set = merge_with_two_avg_col.copy()

cleaned_tv_shows = cleaned_data_set[cleaned_data_set["type"] == 'TV Show']

#just movies in clean set
cleaned_movies = cleaned_data_set[cleaned_data_set["type"] == 'Movie']

# %%
#extract the month added and add to a column

dates_parsed = merge_with_two_avg_col.copy()
dates_parsed['month added'] = dates_parsed['date_added'].replace(r'[\d\s,]+' , regex = True, value='')
print(dates_parsed.head(1))

dates_parsed_tv = dates_parsed[dates_parsed["type"] == 'TV Show']
dates_parsed_movie = dates_parsed[dates_parsed["type"] == 'Movie']
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year seasons / movie length      listed_in  \
# 0  September 25, 2021          2020                    90   Documentaries
#
#    ... certificate_y episode / movie length                            genre  \
# 0  ...         PG-13                   89.0  [Documentary, Biography, Drama]
#
#   rating                                      description_y  \
# 0    7.4  A daughter helps her father prepare for the en...
#
#                                                stars  votes average rating  \
# 0  ['Kirsten Johnson', '| ', '    Stars:', 'Micha...  6,636            7.4
#
#   average episode / movie length month added
# 0                           89.0   September
#
# [1 rows x 23 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()
sns.relplot(x='release_year', y='rating', hue="type", data=cleaned_data_set);

# %%
sns.relplot(x='release_year', y='rating', data=cleaned_tv_shows, color='b')

# %%
sns.relplot(x='release_year', y='rating', data=cleaned_movies, color='g')

# %%
sns.relplot(x='average episode / movie length', y='rating', data=cleaned_tv_shows, color='b')

# %%
sns.relplot(x='average episode / movie length', y='rating', data=cleaned_movies, color='g')

# %%
sns.relplot(x="release_year", y="rating", data=cleaned_data_set, hue='type', kind="line")

# %%
sns.relplot(x="release_year", y="rating", data=cleaned_tv_shows, kind="line", color='g')

# %%
sns.relplot(x="release_year", y="rating", data=cleaned_movies, kind="line", color='b')

# %%
sns.catplot(data=cleaned_data_set, x="type", y="rating", kind="box")

# %%
sns.displot(data=cleaned_tv_shows, x="rating", color='g')

# %%
sns.displot(data=cleaned_movies, x="rating")

# %%
graph = sns.relplot(x="month added", y="rating", data=dates_parsed_tv, kind="line", color='g')
graph.set_xticklabels(rotation=45)

# %%
graph = sns.relplot(x="month added", y="rating", data=dates_parsed_movie, kind="line", color='g')
graph.set_xticklabels(rotation=45)

# %%
proper_tv_ratings_mask = ((cleaned_tv_shows['certificate_y'] == 'TV-14') | 
(cleaned_tv_shows['certificate_y'] == 'TV-MA') |
(cleaned_tv_shows['certificate_y'] == 'TV-PG') | 
(cleaned_tv_shows['certificate_y'] == 'TV-Y7') |
(cleaned_tv_shows['certificate_y'] == 'TV-Y') |
(cleaned_tv_shows['certificate_y'] == 'TV-Y7-FV') |
(cleaned_tv_shows['certificate_y'] == 'TV-G'))

proper_tv_ratings = cleaned_tv_shows[proper_tv_ratings_mask]


proper_movie_ratings_mask = ((cleaned_movies['certificate_y'] == 'PG-13') |
                             (cleaned_movies['certificate_y'] == 'PG') |
                             (cleaned_movies['certificate_y'] == 'R') |
                            (cleaned_movies['certificate_y'] == 'G') |
                            (cleaned_movies['certificate_y'] == 'NC-17'))
proper_movie_ratings = cleaned_movies[proper_movie_ratings_mask]

# %%
graph = sns.catplot(data=dates_parsed, x="certificate_y", y="rating", kind="box")
graph.set_xticklabels(rotation=45)

# %%
graph = sns.catplot(data=proper_tv_ratings, x="certificate_y", y="rating", kind="box")
graph.set_xticklabels(rotation=45)

# %%
graph = sns.catplot(data=proper_movie_ratings, x="certificate_y", y="rating", kind="box")
graph.set_xticklabels(rotation=45)

# %%
#rating_x is maturity rating, which is already listed as certificate. drop rating_x bc of redundancy?
    #combined them certificate
#rating_y is imdb rating
#before merge, if we wanted to preserve those titles listed in netflix_titles without an indication of tv or movie, 
#we could use a regex from certificate
    #BUT, the merged data just based on title still has 4600+ rows, so not necessary

#1) Group by title and then take average imdb rating to account for different episodes listed
    #could also do the same to get the average episode length
#2) duration_x either gives movie length or it gives number of seasons (for tv show) 
    #duration_y gives movie length or length of a single episode
    #if we wanted to calculate some figure that depends on content length and imdb rating, we could do a visualization for tv shows
    #either dependent on number of seasons or average episode length in the group_by indicated in #1)
